# %%
import pandas as pd

df = pd.read_csv("andmed/toorandmed.csv")

# Andmepunktide (ridade) ja tunnuste (veergude) arv
print(f"Andmepunktide arv (read): {df.shape[0]}")
print(f"Tunnuste arv (veerud):    {df.shape[1]}")
print(f"Kogu andmepunkte:         {df.shape[0] * df.shape[1]}")
# Out:
# Andmepunktide arv (read): 3031
# Tunnuste arv (veerud):    223
# Kogu andmepunkte:         675913

# %%
# Ühe andmerea (esimese aine) põhjalik läbivaatus
rida = df.iloc[0]

# Kuvame kõik tunnused ja nende väärtused
pd.set_option("display.max_colwidth", 120)
pd.set_option("display.max_rows", 250)

print(f"Aine: {rida['title__et']} ({rida['code']})\n")
print(f"{'='*60}")
print(f"Tunnuseid kokku: {len(rida)}")
print(f"Tühjad (NaN) väärtused: {rida.isna().sum()}")
print(f"Täidetud väärtused: {rida.notna().sum()}")
print(f"{'='*60}\n")

# Kuvame kõik veerud ja väärtused
for col in df.columns:
    val = rida[col]
    tyyp = type(val).__name__
    on_tyhi = pd.isna(val) if not isinstance(val, str) else (val.strip() == "")
    print(f"  {col}")
    print(f"    Tüüp: {tyyp} | Tühi: {on_tyhi}")
    if isinstance(val, str) and len(val) > 200:
        print(f"    Väärtus: {val[:200]}...")
    else:
        print(f"    Väärtus: {val}")
    print()
# Out:
# Aine: Mikrobioloogia ja viroloogia praktikum (LOMR.03.021)
#
# ============================================================
# Tunnuseid kokku: 223
# Tühjad (NaN) väärtused: 91
# Täidetud väärtused: 132
# ============================================================
#
#   course_uuid
#     Tüüp: str | Tühi: False
#     Väärtus: eefb3a8d-7669-a5dc-9e13-6f95d719ebdf
#
#   code
#     Tüüp: str | Tühi: False
#     Väärtus: LOMR.03.021
#
#   title__en
#     Tüüp: str | Tühi: False
#     Väärtus: Practical Course of Microbiology and Virology
#
#   version__title__en
#     Tüüp: str | Tühi: False
#     Väärtus: Practical Course of Microbiology and Virology
#
#   credits
#     Tüüp: float64 | Tühi: False
#     Väärtus: 6.0
#
#   overview__description__en
#     Tüüp: str | Tühi: False
#     Väärtus: Gaining practical skills to work with microbes and bacteriophages, doing research, growing and identifying microbes and bacteriophages.
#
#   version__overview__description__en
#     Tüüp: str | Tühi: False
#     Väärtus: Gaining practical skills to work with microbes and bacteriophages, doing research, growing and identifying microbes and bacteriophages.
#
#   overview__learning_outcomes_text_en
#     Tüüp: str | Tühi: False
#     Väärtus: - After the course students are expected to:
# - - know how to work safely with different microbes and bacteriophages
# - - have acquired the skills to use basic microbiological methods in different appli...
#
#   uuid
#     Tüüp: str | Tühi: False
#     Väärtus: eefb3a8d-7669-a5dc-9e13-6f95d719ebdf
#
#   state__code
#     Tüüp: str | Tühi: False
#     Väärtus: confirmed
#
#   state__et
#     Tüüp: str | Tühi: False
#     Väärtus: Kinnitatud
#
#   state__en
#     Tüüp: str | Tühi: False
#     Väärtus: confirmed
#
#   last_update
#     Tüüp: str | Tühi: False
#     Väärtus: 2024-02-05T11:04:36
#
#   title__et
#     Tüüp: str | Tühi: False
#     Väärtus: Mikrobioloogia ja viroloogia praktikum
#
#   general__input_languages
#     Tüüp: str | Tühi: False
#     Väärtus: [{"code": "en", "en": "English", "et": "inglise keel"}]
#
#   general__structural_unit_shares
#     Tüüp: str | Tühi: False
#     Väärtus: [{"coordinating": true, "course_share_percent": 100, "structural_unit_code": "LTMR03", "structural_unit_name": {"en": "Chair of Genetics", "et": "geneetika õppetool"}}]
#
#   general__type__code
#     Tüüp: str | Tühi: False
#     Väärtus: regular
#
#   general__type__et
#     Tüüp: str | Tühi: False
#     Väärtus: Tavaline aine
#
#   general__type__en
#     Tüüp: str | Tühi: False
#     Väärtus: Regular course
#
#   general__structural_units
#     Tüüp: str | Tühi: False
#     Väärtus: [{"academic": true, "address": "Riia 23, ruumid 101-117, 301, 302\n51010 Tartu linn, \nTartu linn, Tartumaa \nEST", "city": "Tartu linn", "code": "LTMR03", "level": 3, "name": {"en": "Chair of Genetic...
#
#   additional_info__duration_in_semesters
#     Tüüp: int64 | Tühi: False
#     Väärtus: 1
#
#   additional_info__assessment_scale__code
#     Tüüp: str | Tühi: False
#     Väärtus: grade
#
#   additional_info__assessment_scale__et
#     Tüüp: str | Tühi: False
#     Väärtus: Eristav (A, B, C, D, E, F, mi)
#
#   additional_info__assessment_scale__en
#     Tüüp: str | Tühi: False
#     Väärtus: differentiated (A, B, C, D, E, F, not present)
#
#   additional_info__is_vota_course
#     Tüüp: bool | Tühi: False
#     Väärtus: True
#
#   additional_info__is_continuous_learning_course
#     Tüüp: bool | Tühi: False
#     Väärtus: False
#
#   additional_info__prerequisites
#     Tüüp: str | Tühi: False
#     Väärtus: [{"code": "LOMR.03.010", "credits": 3, "last_update": "2024-02-05T11:04:36", "required": true, "state": {"code": "confirmed", "en": "confirmed", "et": "Kinnitatud"}, "title": {"en": "Genetics I", "et"...
#
#   overview__description__et
#     Tüüp: str | Tühi: False
#     Väärtus: Praktilise töö kogemuste saamine mikroobidega ja mikroobe nakatavate viirustega (bakteriofaagide) töötamiseks. Tutvutakse mikroobide ja bakterifaagide erinevate uurimisviisidega, nende kultiveerimise ...
#
#   overview__objectives
#     Tüüp: str | Tühi: False
#     Väärtus: [{"en": "The aim of the Practical Course of Microbiology and Virology is to provide basic knowledge in understanding microorganisms and in handling them safely. Various experiments have been chosen to...
#
#   overview__learning_outcomes
#     Tüüp: str | Tühi: False
#     Väärtus: [{"en": "After the course students are expected to:", "et": "Peale kursuse läbimist üliõpilane:"}, {"en": "- know how to work safely with different microbes and bacteriophages", "et": "- oskab ohutult...
#
#   _actions__is_editable
#     Tüüp: bool | Tühi: False
#     Väärtus: False
#
#   _actions__is_version_creatable
#     Tüüp: bool | Tühi: False
#     Väärtus: False
#
#   _actions__is_deletable
#     Tüüp: bool | Tühi: False
#     Väärtus: False
#
#   overview__objectives_text_en
#     Tüüp: str | Tühi: False
#     Väärtus: - The aim of the Practical Course of Microbiology and Virology is to provide basic knowledge in understanding microorganisms and in handling them safely. Various experiments have been chosen to help s...
#
#   version__uuid
#     Tüüp: str | Tühi: False
#     Väärtus: b8342470-93bc-fd9b-65a6-42b9ea4d937a
#
#   version__state__code
#     Tüüp: str | Tühi: False
#     Väärtus: confirmed
#
#   version__state__et
#     Tüüp: str | Tühi: False
#     Väärtus: Kinnitatud
#
#   version__state__en
#     Tüüp: str | Tühi: False
#     Väärtus: confirmed
#
#   version__last_update
#     Tüüp: str | Tühi: False
#     Väärtus: 2026-01-15T19:19:53
#
#   version__title__et
#     Tüüp: str | Tühi: False
#     Väärtus: Mikrobioloogia ja viroloogia praktikum
#
#   version__credits
#     Tüüp: float64 | Tühi: False
#     Väärtus: 2.0
#
#   version__credit_type
#     Tüüp: str | Tühi: False
#     Väärtus: ECTS
#
#   version__target__year__code
#     Tüüp: float64 | Tühi: False
#     Väärtus: 2025.0
#
#   version__target__year__et
#     Tüüp: str | Tühi: False
#     Väärtus: 2025/2026
#
#   version__target__year__en
#     Tüüp: str | Tühi: False
#     Väärtus: 2025/2026
#
#   version__target__semester__code
#     Tüüp: str | Tühi: False
#     Väärtus: autumn
#
#   version__target__semester__et
#     Tüüp: str | Tühi: False
#     Väärtus: sügis
#
#   version__target__semester__en
#     Tüüp: str | Tühi: False
#     Väärtus: autumn
#
#   version__target__study_type__code
#     Tüüp: str | Tühi: False
#     Väärtus: fulltime
#
#   version__target__study_type__et
#     Tüüp: str | Tühi: False
#     Väärtus: päevaõpe
#
#   version__target__study_type__en
#     Tüüp: str | Tühi: False
#     Väärtus: regular studies
#
#   version__target__language__code
#     Tüüp: str | Tühi: False
#     Väärtus: et
#
#   version__target__language__et
#     Tüüp: str | Tühi: False
#     Väärtus: eesti keel
#
#   version__target__language__en
#     Tüüp: str | Tühi: False
#     Väärtus: Estonian
#
#   version__target__part__code
#     Tüüp: float64 | Tühi: False
#     Väärtus: 2.0
#
#   version__target__part__et
#     Tüüp: str | Tühi: False
#     Väärtus: 2. osa
#
#   version__target__part__en
#     Tüüp: str | Tühi: False
#     Väärtus: part 2
#
#   version__target__part_credits
#     Tüüp: float64 | Tühi: False
#     Väärtus: 2.0
#
#   version__target__faculty__code
#     Tüüp: str | Tühi: False
#     Väärtus: LT
#
#   version__target__faculty__name__en
#     Tüüp: str | Tühi: False
#     Väärtus: Faculty of Science and Technology
#
#   version__target__faculty__name__et
#     Tüüp: str | Tühi: False
#     Väärtus: loodus- ja täppisteaduste valdkond
#
#   version__target__faculty__address
#     Tüüp: str | Tühi: False
#     Väärtus: Tartu linn,
# Tartu linn, Tartumaa
# EST
#
#   version__target__faculty__city
#     Tüüp: str | Tühi: False
#     Väärtus: Tartu linn
#
#   version__target__faculty__level
#     Tüüp: float64 | Tühi: False
#     Väärtus: 1.0
#
#   version__target__faculty__academic
#     Tüüp: bool | Tühi: False
#     Väärtus: True
#
#   version__target__faculty__supports_continuous_learning
#     Tüüp: bool | Tühi: False
#     Väärtus: True
#
#   version__target__course_main_structural_unit__code
#     Tüüp: str | Tühi: False
#     Väärtus: LTMR03
#
#   version__target__course_main_structural_unit__name__en
#     Tüüp: str | Tühi: False
#     Väärtus: Chair of Genetics
#
#   version__target__course_main_structural_unit__name__et
#     Tüüp: str | Tühi: False
#     Väärtus: geneetika õppetool
#
#   version__target__course_main_structural_unit__phone
#     Tüüp: str | Tühi: False
#     Väärtus: +372 737 5014
#
#   version__target__course_main_structural_unit__address
#     Tüüp: str | Tühi: False
#     Väärtus: Riia 23, ruumid 101-117, 301, 302
# 51010 Tartu linn,
# Tartu linn, Tartumaa
# EST
#
#   version__target__course_main_structural_unit__city
#     Tüüp: str | Tühi: False
#     Väärtus: Tartu linn
#
#   version__target__course_main_structural_unit__street
#     Tüüp: str | Tühi: False
#     Väärtus: Riia 23, ruumid 101-117, 301, 302
#
#   version__target__course_main_structural_unit__zip
#     Tüüp: float64 | Tühi: False
#     Väärtus: 51010.0
#
#   version__target__course_main_structural_unit__level
#     Tüüp: float64 | Tühi: False
#     Väärtus: 3.0
#
#   version__target__course_main_structural_unit__academic
#     Tüüp: bool | Tühi: False
#     Väärtus: True
#
#   version__target__course_main_structural_unit__supports_continuous_learning
#     Tüüp: bool | Tühi: False
#     Väärtus: False
#
#   version__target__course_main_structural_unit__parent_code
#     Tüüp: str | Tühi: False
#     Väärtus: LTMR
#
#   version__target__label__en
#     Tüüp: str | Tühi: False
#     Väärtus: 25/26 A regular part 2 2 CP LT
#
#   version__target__label__et
#     Tüüp: str | Tühi: False
#     Väärtus: 25/26 S PÕ 2. osa 2 EAP LT
#
#   version__general__year__code
#     Tüüp: float64 | Tühi: False
#     Väärtus: 2025.0
#
#   version__general__year__et
#     Tüüp: str | Tühi: False
#     Väärtus: 2025/2026
#
#   version__general__year__en
#     Tüüp: str | Tühi: False
#     Väärtus: 2025/2026
#
#   version__general__input_languages
#     Tüüp: str | Tühi: False
#     Väärtus: [{"code": "et", "en": "Estonian", "et": "eesti keel"}]
#
#   version__general__structural_unit_shares
#     Tüüp: str | Tühi: False
#     Väärtus: [{"coordinating": true, "course_share_percent": 100, "structural_unit_code": "LTMR03", "structural_unit_name": {"en": "Chair of Genetics", "et": "geneetika õppetool"}}]
#
#   version__general__type__code
#     Tüüp: str | Tühi: False
#     Väärtus: regular
#
#   version__general__type__et
#     Tüüp: str | Tühi: False
#     Väärtus: Tavaline aine
#
#   version__general__type__en
#     Tüüp: str | Tühi: False
#     Väärtus: Regular course
#
#   version__additional_info__is_vota_course
#     Tüüp: bool | Tühi: False
#     Väärtus: True
#
#   version__additional_info__is_continuous_learning_course
#     Tüüp: bool | Tühi: False
#     Väärtus: False
#
#   version__additional_info__study_levels
#     Tüüp: str | Tühi: False
#     Väärtus: [{"code": "bachelor", "en": "bachelor's studies", "et": "bakalaureuseõpe"}]
#
#   version__additional_info__hours__lecture
#     Tüüp: float64 | Tühi: False
#     Väärtus: 0.0
#
#   version__additional_info__hours__practice
#     Tüüp: float64 | Tühi: False
#     Väärtus: 20.0
#
#   version__additional_info__hours__seminar
#     Tüüp: float64 | Tühi: False
#     Väärtus: 0.0
#
#   version__additional_info__hours__colloquium
#     Tüüp: float64 | Tühi: False
#     Väärtus: 0.0
#
#   version__additional_info__hours__web_learning
#     Tüüp: float64 | Tühi: False
#     Väärtus: 0.0
#
#   version__additional_info__hours__independent_work
#     Tüüp: float64 | Tühi: False
#     Väärtus: 32.0
#
#   version__additional_info__hours__individual_work
#     Tüüp: float64 | Tühi: False
#     Väärtus: 0.0
#
#   version__additional_info__hours__internship
#     Tüüp: float64 | Tühi: False
#     Väärtus: 0.0
#
#   version__additional_info__is_enlight_course
#     Tüüp: bool | Tühi: False
#     Väärtus: False
#
#   version__overview__study_languages
#     Tüüp: str | Tühi: False
#     Väärtus: [{"code": "et", "en": "Estonian", "et": "eesti keel"}]
#
#   version__overview__description__et
#     Tüüp: str | Tühi: False
#     Väärtus: Praktilise töö kogemuste saamine mikroobidega ja mikroobe nakatavate viirustega (bakteriofaagide) töötamiseks. Tutvutakse mikroobide ja bakterifaagide erinevate uurimisviisidega, nende kultiveerimise ...
#
#   version__overview__objectives
#     Tüüp: str | Tühi: False
#     Väärtus: [{"en": "The aim of the Practical Course of Microbiology and Virology is to provide basic knowledge in understanding microorganisms and in handling them safely. Various experiments have been chosen to...
#
#   version__overview__learning_outcomes
#     Tüüp: str | Tühi: False
#     Väärtus: [{"en": "After the course students are expected to:", "et": "Peale kursuse läbimist üliõpilane:"}, {"en": "- know how to work safely with different microbes and bacteriophages", "et": "- oskab ohutult...
#
#   version__grading__independent_work_assessments
#     Tüüp: str | Tühi: False
#     Väärtus: [{"description": {"et": "Praktikumi eesmärk on anda tudengitele praktilisi oskusi. Lisaks põhjendatakse kuidas tehakse teadustöö katseid ning selgitatakse meetodite eripärasid (teoreetilised teadmised...
#
#   version__grading__grade_preconditions__et
#     Tüüp: str | Tühi: False
#     Väärtus: Kõigis praktikumides osalemine.
#
#   version__grading__grade_evaluation__et
#     Tüüp: str | Tühi: False
#     Väärtus: Jooksev hindamine. Vaata hindamiskriteeriume.
#
#   version__grading__debt_elimination__et
#     Tüüp: str | Tühi: False
#     Väärtus: Kokkuleppel õppejõuga
#
#   version__grading__assessment_scale__code
#     Tüüp: str | Tühi: False
#     Väärtus: grade
#
#   version__grading__assessment_scale__et
#     Tüüp: str | Tühi: False
#     Väärtus: Eristav (A, B, C, D, E, F, mi)
#
#   version__grading__assessment_scale__en
#     Tüüp: str | Tühi: False
#     Väärtus: differentiated (A, B, C, D, E, F, not present)
#
#   version__resources__web_based__code
#     Tüüp: float64 | Tühi: False
#     Väärtus: 2.0
#
#   version__resources__web_based__et
#     Tüüp: str | Tühi: False
#     Väärtus: põimõpe
#
#   version__resources__web_based__en
#     Tüüp: str | Tühi: False
#     Väärtus: blended learning
#
#   version__resources__website_url
#     Tüüp: str | Tühi: False
#     Väärtus: http://moodle.ut.ee
#
#   version__resources__is_moodle_connected
#     Tüüp: bool | Tühi: False
#     Väärtus: True
#
#   version__resources__learning_environments
#     Tüüp: str | Tühi: False
#     Väärtus: [{"base_url": "https://moodle.ut.ee/local/ois", "code": "LOMR.03.021_2osa", "is_auto_grading": false, "is_auto_update": false, "is_default": true, "linked_to_groups": ["11c9ae52-e8bd-74bd-38bb-c2eb43e...
#
#   version__participants__lecturers
#     Tüüp: str | Tühi: False
#     Väärtus: [{"is_responsible": true, "is_teaching": true, "person_name": "Riho Teras", "person_uuid": "a2326732-0876-a667-fd89-19cd542f634e", "structural_unit": {"academic": true, "address": "Riia 23, ruumid 101...
#
#   version__participants__study_groups
#     Tüüp: str | Tühi: False
#     Väärtus: [{"code": "1. rühm", "max_size": 20, "uuid": "11c9ae52-e8bd-74bd-38bb-c2eb43e22b00"}, {"code": "2. rühm", "max_size": 20, "uuid": "192134bd-7785-b110-711b-614e7ebf85c6"}, {"code": "3. rühm", "max_size...
#
#   version__schedule__weeks__et
#     Tüüp: str | Tühi: False
#     Väärtus: 20 või 21n 20Pn=> E;
#
#   version__schedule__entries
#     Tüüp: str | Tühi: False
#     Väärtus: [{"description": {"et": "1. tööle sissejuhatus \"Horisontaalne geeniülekanne\". Selles töös vaadeldakse horisontaalse geeniülekande toimumist bakteritel, täpsemalt, mis saab faaginakkuse järel lüüsunu...
#
#   version__registration_info__min_students
#     Tüüp: float64 | Tühi: False
#     Väärtus: 5.0
#
#   version__registration_info__max_students
#     Tüüp: float64 | Tühi: False
#     Väärtus: 80.0
#
#   version__parent_uuid
#     Tüüp: str | Tühi: False
#     Väärtus: eefb3a8d-7669-a5dc-9e13-6f95d719ebdf
#
#   version__parent_code
#     Tüüp: str | Tühi: False
#     Väärtus: LOMR.03.021
#
#   version__parent_credits
#     Tüüp: float64 | Tühi: False
#     Väärtus: 6.0
#
#   version___actions__is_editable
#     Tüüp: bool | Tühi: False
#     Väärtus: False
#
#   version___actions__is_moodle_editable
#     Tüüp: bool | Tühi: False
#     Väärtus: False
#
#   version___actions__is_deletable
#     Tüüp: bool | Tühi: False
#     Väärtus: False
#
#   version__overview__objectives_text_en
#     Tüüp: str | Tühi: False
#     Väärtus: - The aim of the Practical Course of Microbiology and Virology is to provide basic knowledge in understanding microorganisms and in handling them safely. Various experiments have been chosen to help s...
#
#   version__overview__learning_outcomes_text_en
#     Tüüp: str | Tühi: False
#     Väärtus: - After the course students are expected to:
# - - know how to work safely with different microbes and bacteriophages
# - - have acquired the skills to use basic microbiological methods in different appli...
#
#   latest_version_uuid
#     Tüüp: str | Tühi: False
#     Väärtus: b8342470-93bc-fd9b-65a6-42b9ea4d937a
#
#   additional_info__occurrence_frequency__code
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   additional_info__occurrence_frequency__et
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   additional_info__occurrence_frequency__en
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__target__course_main_structural_unit__webpage_url
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__grading__independent_work__et
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__resources__mandatory_materials
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__resources__recommended_materials
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__target__course_main_structural_unit__email
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__resources__materials
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__participants__assistants
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__overview__notes__et
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__registration_info__audience__et
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__confirmation_process__confirmation_uuid
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__confirmation_process__state_code
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__confirmation_process__is_paused
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__code
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__grading__grade_conditions__A__et
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__grading__grade_conditions__B__et
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__grading__grade_conditions__C__et
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__grading__grade_conditions__D__et
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__grading__grade_conditions__E__et
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__grading__grade_conditions__F__et
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__target__course_main_structural_unit__is_expired
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__grading__grade_conditions__arvestatud__et
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   additional_info__language_training__language__code
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   additional_info__language_training__language__et
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   additional_info__language_training__language__en
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__overview__other_languages
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__grading__grade_conditions__mittearvestatud__et
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__grading__min_points_from_tests
#     Tüüp: float64 | Tühi: True
#     Väärtus: nan
#
#   version__grading__results_available_from__et
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   additional_info__language_training__start_level__code
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   additional_info__language_training__start_level__et
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   additional_info__language_training__start_level__en
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__grading__grade_conditions__mi__et
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__grading__grade_conditions__mitteilmunud__et
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__overview__notes__en
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__grading__independent_work__en
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__grading__grade_preconditions__en
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__grading__grade_evaluation__en
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__grading__debt_elimination__en
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__grading__results_available_from__en
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__resources__library_package
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__additional_info__language_training__language__code
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__additional_info__language_training__language__et
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__additional_info__language_training__language__en
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__additional_info__language_training__start_level__code
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__additional_info__language_training__start_level__et
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__additional_info__language_training__start_level__en
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__additional_info__language_training__end_level__code
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__additional_info__language_training__end_level__et
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__additional_info__language_training__end_level__en
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   additional_info__complex_course_sub_courses
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   additional_info__language_training__end_level__code
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   additional_info__language_training__end_level__et
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   additional_info__language_training__end_level__en
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__grading__grade_conditions__A__en
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__grading__grade_conditions__B__en
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__grading__grade_conditions__C__en
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__grading__grade_conditions__D__en
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__grading__grade_conditions__E__en
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__grading__grade_conditions__F__en
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__grading__grade_conditions__mi__en
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__confirmation_process__comment
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   additional_info__language_training__is_in_depth_estonian_training
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__additional_info__language_training__is_in_depth_estonian_training
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   overview__description__fr
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__grading__grade_conditions__arvestatud__en
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__grading__grade_conditions__mittearvestatud__en
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__grading__grade_conditions__mitteilmunud__en
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   title__ru
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__title__ru
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__target__faculty__phone
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__target__faculty__street
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__target__faculty__zip
#     Tüüp: float64 | Tühi: True
#     Väärtus: nan
#
#   version__target__faculty__parent_code
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__target__faculty__email
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__target__faculty__webpage_url
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__target__faculty__is_expired
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   overview__description__ru
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   title__es
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   overview__description__es
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__title__es
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__overview__description__es
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   title__de
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__title__de
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   overview__description__de
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   title__vro
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   overview__description__vro
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__title__vro
#     Tüüp: float | Tühi: True
#     Väärtus: nan
#
#   version__overview__description__vro
#     Tüüp: float | Tühi: True
#     Väärtus: nan

# %%
# Tähelepanekud tunnuste vorminduse kohta
rida = df.iloc[0]

print("=== TÄHELEPANEKUD TUNNUSTE VORMINDUSE KOHTA ===\n")

# 1. JSON-sõned (listid/sõnastikud stringina)
json_veerud = []
for col in df.columns:
    val = rida[col]
    if isinstance(val, str) and (val.strip().startswith("[{") or val.strip().startswith("{")):
        json_veerud.append(col)
print(f"1) JSON-vormingus sõned (list/dict stringina): {len(json_veerud)} tk")
for v in json_veerud[:5]:
    print(f"   - {v}: {str(rida[v])[:100]}...")
print()

# 2. Mitmekeelsed tunnused (en/et paarid)
en_veerud = [c for c in df.columns if c.endswith("__en")]
et_veerud = [c for c in df.columns if c.endswith("__et")]
print(f"2) Mitmekeelsed tunnused:")
print(f"   - Ingliskeelsed (__en): {len(en_veerud)} tk")
print(f"   - Eestikeelsed (__et):  {len(et_veerud)} tk")
print()

# 3. Hierarhiline nimetus (__ eraldajaga)
tasemete_arv = [col.count("__") for col in df.columns]
print(f"3) Hierarhiline nimetusstruktuur (__ eraldajaga):")
print(f"   - Max pesastumissügavus: {max(tasemete_arv)} taset")
print(f"   - Näide sügavaimast: {df.columns[tasemete_arv.index(max(tasemete_arv))]}")
print()

# 4. Tühjad väärtused
tyhjad = rida.isna().sum()
print(f"4) Tühjad väärtused selles reas: {tyhjad}/{len(rida)} ({tyhjad/len(rida)*100:.1f}%)")
print()

# 5. Andmetüübid
print(f"5) Veergude andmetüübid:")
for dtype, count in df.dtypes.value_counts().items():
    print(f"   - {dtype}: {count} veergu")
print()

# 6. UUID-d
uuid_veerud = [c for c in df.columns if "uuid" in c.lower()]
print(f"6) UUID-tunnused: {len(uuid_veerud)} tk")
for v in uuid_veerud:
    print(f"   - {v}")
print()

# 7. Kuupäevad
date_veerud = [c for c in df.columns if "update" in c.lower() or "date" in c.lower()]
print(f"7) Kuupäeva/aja tunnused: {len(date_veerud)} tk")
for v in date_veerud:
    print(f"   - {v}: {rida[v]}")
print()

# 8. Boolean tunnused
bool_veerud = [c for c in df.columns if rida[c] in [True, False, "True", "False"]]
print(f"8) Tõeväärtus (boolean) tunnused: {len(bool_veerud)} tk")
for v in bool_veerud[:5]:
    print(f"   - {v}: {rida[v]}")
if len(bool_veerud) > 5:
    print(f"   ... ja veel {len(bool_veerud) - 5} tk")
# Out:
# === TÄHELEPANEKUD TUNNUSTE VORMINDUSE KOHTA ===
#
# 1) JSON-vormingus sõned (list/dict stringina): 17 tk
#    - general__input_languages: [{"code": "en", "en": "English", "et": "inglise keel"}]...
#    - general__structural_unit_shares: [{"coordinating": true, "course_share_percent": 100, "structural_unit_code": "LTMR03", "structural_u...
#    - general__structural_units: [{"academic": true, "address": "Riia 23, ruumid 101-117, 301, 302\n51010 Tartu linn, \nTartu linn, T...
#    - additional_info__prerequisites: [{"code": "LOMR.03.010", "credits": 3, "last_update": "2024-02-05T11:04:36", "required": true, "stat...
#    - overview__objectives: [{"en": "The aim of the Practical Course of Microbiology and Virology is to provide basic knowledge ...
#
# 2) Mitmekeelsed tunnused:
#    - Ingliskeelsed (__en): 43 tk
#    - Eestikeelsed (__et):  45 tk
#
# 3) Hierarhiline nimetusstruktuur (__ eraldajaga):
#    - Max pesastumissügavus: 4 taset
#    - Näide sügavaimast: version__target__faculty__name__en
#
# 4) Tühjad väärtused selles reas: 91/223 (40.8%)
#
# 5) Veergude andmetüübid:
#    - object: 194 veergu
#    - float64: 23 veergu
#    - bool: 5 veergu
#    - int64: 1 veergu
#
# 6) UUID-tunnused: 6 tk
#    - course_uuid
#    - uuid
#    - version__uuid
#    - version__parent_uuid
#    - latest_version_uuid
#    - version__confirmation_process__confirmation_uuid
#
# 7) Kuupäeva/aja tunnused: 2 tk
#    - last_update: 2024-02-05T11:04:36
#    - version__last_update: 2026-01-15T19:19:53
#
# 8) Tõeväärtus (boolean) tunnused: 24 tk
#    - additional_info__duration_in_semesters: 1
#    - additional_info__is_vota_course: True
#    - additional_info__is_continuous_learning_course: False
#    - _actions__is_editable: False
#    - _actions__is_version_creatable: False
#    ... ja veel 19 tk

# %%
# Kontroll: tühjad vs täidetud tunnused
rida = df.iloc[0]
print(f"Tühjad (NaN):  {rida.isna().sum()}")
print(f"Täidetud:      {rida.notna().sum()}")
print(f"Kokku:         {len(rida)}")
# Out:
# Tühjad (NaN):  91
# Täidetud:      132
# Kokku:         223

# %% [markdown]
# ## Üldised tähelepanekud andmerea kohta
#
# Toorandmestik sisaldab **3031 ainet** (andmepunkti) ja **223 tunnust** – tegemist on väga laia andmestikuga, kus ühe aine kohta on salvestatud rohkelt metaandmeid. Vaadeldud esimene andmerida kirjeldab ainet **"Mikrobioloogia ja viroloogia praktikum" (LOMR.03.021)**.
#
# **Peamised tähelepanekud:**
#
# - **Suur tühjuse osakaal:** isegi esimeses reas on 91 tunnust 223-st (40,8%) tühjad, mis viitab sellele, et paljud väljad on valikulised või kehtivad ainult teatud ainete puhul (nt keeleõppe tunnused, hindamistingimused hindele A–F jne).
# - **Pesastatud JSON-sõned:** 17 veergu sisaldavad andmeid JSON-vormingus stringina (nt õppejõud, struktuuriüksused, eeldusained, õpiväljundid). Nende kasutamiseks tuleb need eraldi parsida.
# - **Mitmekeelsus:** andmestik sisaldab paralleelselt eesti- ja ingliskeelseid tunnuseid (~45 et/~43 en lõpuga veergu), mis dubleerivad infot eri keeltes.
# - **Hierarhiline veergude struktuur:** veergude nimed kasutavad topelt-allkriipsu (`__`) eraldajana pesastatud info tähistamiseks (nt `version__target__faculty__name__en`), sügavusega kuni 4 taset. See viitab algandmete API pesastatud JSON-struktuurile.
# - **UUID-d identifikaatoritena:** ainete identifitseerimiseks kasutatakse UUID-formaadis tunnuseid (6 tk), mitte ainult ainekoodide.
# - **Kuupäevad ISO-formaadis:** ajatemplid on ISO 8601 vormingus stringidena (nt `2024-02-05T11:04:36`), mida peaks analüüsiks datetime-tüübiks teisendama.
# - **Andmetüübid on peamiselt tekstilised:** 194 veergu 223-st on `object`-tüüpi, mis tähendab, et enamik andmeid on sõned (sh numbrilised ja boolean-väärtused, mis vajavad teisendamist).
